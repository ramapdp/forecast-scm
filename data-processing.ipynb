# %%
import pandas as pd
import numpy as np

def load_data(file_path):
    """
    Load data from a CSV file into a pandas DataFrame.

    Parameters:
    file_path (str): The path to the CSV file.

    Returns:
    pd.DataFrame: A DataFrame containing the loaded data.
    """
    try:
        data = pd.read_csv(file_path, sep=';')
        return data
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

# %%
dataset = load_data('dataset/dataset.csv')

print("Data loaded successfully. Here are the first few rows:")
print(dataset.head())
# Out:
# Data loaded successfully. Here are the first few rows:
#        Tanggal         Kategori Barang Kode Barang        Nama Barang  \
# 0  01 Jan 2024  Barang Semi FG (WIP-2)   FGS-00001  Ayam Kebuli (0.9)
# 1  01 Jan 2024  Barang Semi FG (WIP-2)   FGS-00002     Kambing Kebuli
# 2  01 Jan 2024  Barang Semi FG (WIP-2)   FGS-00003    Iga Sapi Kebuli
# 3  01 Jan 2024  Barang Semi FG (WIP-2)   FGS-00004        Nasi Kebuli
# 4  01 Jan 2024  Barang Semi FG (WIP-2)   FGS-00005        Sambal - FG
#
#                              Nama Cabang  Satuan  Kuantitas
# 0  KY001 - Kebuli Yaman Kutabumi (Pusat)  Potong        235
# 1  KY001 - Kebuli Yaman Kutabumi (Pusat)   Porsi          3
# 2  KY001 - Kebuli Yaman Kutabumi (Pusat)   Porsi          7
# 3  KY001 - Kebuli Yaman Kutabumi (Pusat)   Porsi        256
# 4  KY001 - Kebuli Yaman Kutabumi (Pusat)   Porsi        263

# %%
# dataset.to_excel('dataset/excel/exported_clean_data.xlsx', index=False)

# print("Export complete!")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693565 entries, 0 to 693564
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Tanggal          693565 non-null  object
#  1   Kategori Barang  693565 non-null  object
#  2   Kode Barang      693565 non-null  object
#  3   Nama Barang      693565 non-null  object
#  4   Nama Cabang      693565 non-null  object
#  5   Satuan           693565 non-null  object
#  6   Kuantitas        693565 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 37.0+ MB

# %% [markdown]
# ### Make sure complete data from jan 24 - dec 25

# %%
dataset['Tanggal'] = pd.to_datetime(dataset['Tanggal'])

start_date = dataset['Tanggal'].min()
end_date = dataset['Tanggal'].max()

print(f"Checking data from {start_date.strftime('%d %b %Y')} to {end_date.strftime('%d %b %Y')}")
print("-" * 40)

expected_dates = pd.date_range(start=start_date, end=end_date)

actual_dates = dataset['Tanggal'].dropna().unique()

missing_dates = expected_dates.difference(actual_dates)

if missing_dates.empty:
    print("Your daily data is complete! No missing dates.")
else:
    print(f"You are missing data for {len(missing_dates)} days.")
    print("Missing dates:")
    print(missing_dates.strftime('%d %b %Y').tolist())
# Out:
# Checking data from 01 Jan 2024 to 31 Dec 2025
# ----------------------------------------
# Your daily data is complete! No missing dates.

# %% [markdown]
# ### Check duplicated data

# %%
total_duplicates = dataset.duplicated().sum()
print(f"Total duplicate rows: {total_duplicates}")
print("-" * 40)

# (keep=False ensures we see the original row AND its duplicates)
duplicates = dataset[dataset.duplicated(keep=False)]

if total_duplicates > 0:
    print("Here is a peek at the duplicate rows:")
    print(duplicates.sort_values(by=['Tanggal', 'Kode Barang', 'Nama Cabang']).head(10))
else:
    print("Your dataset is clean! No identical duplicate rows found.")
# Out:
# Total duplicate rows: 0
# ----------------------------------------
# Your dataset is clean! No identical duplicate rows found.

# %%
business_duplicates = dataset.duplicated(subset=['Tanggal', 'Kode Barang', 'Nama Cabang'])
print(f"Duplicates based on specific columns: {business_duplicates.sum()}")
# Out:
# Duplicates based on specific columns: 0

# %% [markdown]
# ### Check missing values

# %%
# Check for missing values in every column
print(dataset.isnull().sum())
# Out:
# Tanggal            0
# Kategori Barang    0
# Kode Barang        0
# Nama Barang        0
# Nama Cabang        0
# Satuan             0
# Kuantitas          0
# dtype: int64

# %%
# Count the number of unique entries per column
print(dataset.nunique())
# Out:
# Tanggal            731
# Kategori Barang     12
# Kode Barang        109
# Nama Barang        112
# Nama Cabang         67
# Satuan              12
# Kuantitas          824
# dtype: int64

# %%
# List the columns you want to inspect
columns_to_check = ['Kategori Barang', 'Kode Barang', 'Nama Barang', 'Nama Cabang', 'Satuan']

# Loop through each column and print its unique contents
for col in columns_to_check:
    print(f"--- Data available in '{col}' ---")
    print(dataset[col].unique())
    print("-" * 50)
# Out:
# --- Data available in 'Kategori Barang' ---
# ['Barang Semi FG (WIP-2)' 'Minuman' 'Packaging' 'Bahan Baku (RM)'
#  'Barang Dalam Process (WIP-1)' 'Snack' 'Barang Umum' 'Perlengkapan Resto'
#  'Minuman - FG' 'Barang Jadi (FG)' 'Snack (FG)' 'Tambahan']
# --------------------------------------------------
# --- Data available in 'Kode Barang' ---
# ['FGS-00001' 'FGS-00002' 'FGS-00003' 'FGS-00004' 'FGS-00005' 'FGS-00009'
#  'FGS-00013' 'FGS-00015' 'FGS-00017' 'PCG-00001' 'PCG-00003' 'PCG-00004'
#  'PCG-00005' 'PCG-00006' 'PCG-00007' 'PCG-00008' 'PCG-00009' 'PCG-00010'
#  'PCG-00011' 'PCG-00012' 'PCG-00013' 'PCG-00024' 'PCG-00030' 'RMT-00017'
#  'FGS-00039' 'FGS-00040' 'FGS-00041' 'PCG-00021' 'FGS-00014' 'FGS-00008'
#  'FGS-00007' 'FGS-00035' 'FGS-00037' 'WIP.00009' 'FGS-00047' 'FGS-00038'
#  'FGS-00056' 'FGS-00006' 'FGS-00012' 'PCG-00036' 'FGS-00042' 'FGS-00043'
#  'FGS-00053' 'FGS-00048' 'FGS.00047' 'FGS-00046' 'FGS-00055' 'FGS-00044'
#  'FGS-00045' 'Kalender' 'FGS-00018' 'PCG-00002' 'PCG-00027' 'PCG-00028'
#  'PCG-00022' 'FGS.00049' 'SPR.00004' 'FGS-00032' 'WIP-00005' 'PCG.00020'
#  'RMT-00015' 'WIP-00003' 'xxx.FGS-00053' 'xxx.FGS-00003' 'FGS.00048'
#  'PCG.00029' 'FGS.00050' 'FGS.00051' 'TMBLR' 'FGS.00052' 'FGS-00034'
#  'FGS.00053' 'FGS.00054' 'xxx.FGS.00067' 'FGS-00011' 'xxx.FGS.00066'
#  'xxx.FGS.00068' 'FGS.00065' 'FGS.00056' 'FGS.00055' 'PCG.00044'
#  'xxx.FGS.00071' 'FGS.00073' 'xxx.FGS.00070' 'FGS.00072' 'xxx.FGS.00069'
#  'xxx.WIP.00010' 'PCG-00038' 'FGS.00071' 'FGS.00069' 'FGS.00070'
#  'WIP-00023-2' 'FGS.00061' 'FGS.00060' 'FGS.00074' 'WIP.00024' 'PCG.00047'
#  'WIP.00030' 'WIP.00025' 'WIP.00022' 'WIP.00031' 'WIP.00023' 'RMT.00074'
#  'WIP.00033' 'APD.00011' 'APD.00010' 'WIP.00026' 'FGS.00075' 'FGS.00076']
# --------------------------------------------------
# --- Data available in 'Nama Barang' ---
# ['Ayam Kebuli (0.9)' 'Kambing Kebuli' 'Iga Sapi Kebuli' 'Nasi Kebuli'
#  'Sambal - FG' 'Dahagaku Lemon Sereh 250ml' 'Samosa Beef Spicy (RM)'
#  'Ichi Ocha Melati 350 ml' 'Susu Almond - FG' 'Lunch Box' 'Loyang Mini'
#  'Loyang Sedang' 'Loyang Besar' 'Box Loyang Mini' 'Box Loyang Sedang'
#  'Box Loyang Besar' 'Cup Sambal Dine in' 'Cup Sambal Take Away'
#  'Cup Sambal Loyang Mini' 'Cup Sambal Loyang Sedang'
#  'Cup Sambal Loyang Besar' 'Botol Sambal' 'Rice Bowl 600 ml'
#  'Saffron Basmati @1kg (RM)' 'Meet Jelly Mangga' 'Meet Jelly Strawberry'
#  'Meet Jelly Leci' 'Gelas 22 Oz'
#  'Club Mineral 600 ml (Menu Pakai Kode CM-600)' '7dates Susu Kurma'
#  '7dates Jus Kurma' 'Gula Asam 250ml' 'Kunyit Asam 250ml' 'Rabeg'
#  'Kentang Mustofa Rumput Laut' 'Meet Jelly Coklat' 'Beef Kebab'
#  'Club Mineral 330 ml' 'Samosa Beef Original (RM)' 'Paper Lunch Tray'
#  'Meet Jelly Kopi Susu' 'Meet Jelly Teh Tarik' 'Ayam Kebuli (0.6)'
#  'Kentang Mustofa Mie Goreng' 'Air Isi Ulang' 'Kentang Mustofa Keju Asin'
#  'Chicken Kebab' 'Kentang Mustofa Rabeg' 'Kentang Mustofa Balado'
#  'Kalender' 'Kambing Kebuli Aqiqah Betina - FG' 'Lunch Box Aqiqah'
#  'Mika Bento' 'Cup 60 ml' 'Sendok' 'Iga Dino - FG' 'Arang'
#  'Le Minerale 600ml' 'Sambal - WIP' 'Alumunium Foil' 'Susu Milk Bar'
#  'Iga Sapi - WIP' 'Club Mineral 330 ml (Menu pakai kode CM-330)'
#  'Gula Asam 250 ml' 'xxx.Ayam Kebuli (0.6)' 'xxx.Iga Sapi Kebuli'
#  'Kunyit Asam 250 ml' 'Kambing Oven - FG' 'Plastik Klip'
#  'AirAlam 600 ml (Menu Pakai Kode AA-600)' 'Iga Jontor - FG'
#  'Merchandise Tumbler' 'Iga Sapi Original - FG'
#  'Kambing Kebuli Aqiqah Jantan - FG' 'AirAlam 330 ml (Menu pakai kode AA)'
#  'India Salaam Basmati Rice @1kg' 'xxx.Ayam Crispy Original - FG'
#  'Saus Extra Delmonte @8gr' 'xxx.Nasi Putih' 'xxx.Ayam Crispy Spicy - FG'
#  'Saus Tomat Delmonte @8gr' 'Saus Spicy' 'Saus Lemon'
#  'Gelas 14 Oz (Cendol)' 'xxx.Gula Cendol - FG' 'Durian'
#  'xxx.Santan Cendol - FG' 'Nangka' 'xxx.Cendol Pandan - FG'
#  'xxx.Ayam (0.6) - WIP' 'Gelas 16 Oz' 'Gula Cendol - FG' 'Cendol - FG'
#  'Santan Cendol - FG' 'Bumbu Presto' 'Green Tea Latte' 'Rendang'
#  'Dahagaku Lemon Tea Madu 250ml' 'Saus Base' 'Packaging Kebab - Small'
#  'Tortilla Medium @22 cm' 'Saus Lava @500gr' 'Ayam Shawarma - WIP'
#  'Tortilla Large @25cm' 'Daging Kebab - WIP' 'Kentang Kebab'
#  'Margarine @500gr' 'Tortilla Small @20cm' 'Packaging Kebab - Large'
#  'Saus Cheese @500gr' 'Teh Tarik Yaman' 'Teh Rempah Yaman']
# --------------------------------------------------
# --- Data available in 'Nama Cabang' ---
# ['KY001 - Kebuli Yaman Kutabumi (Pusat)' 'TOD M1 Bandara'
#  'KY032 - Kebuli Yaman Kelapa Dua Karawaci'
#  'KY022 - Kebuli Yaman Citra Raya' 'KY042 - Kebuli Yaman Batavia'
#  'KY019 - Kebuli Yaman Ciledug' 'KY006 - Kebuli Yaman Depok Sentosa'
#  'KY016 - Kebuli Yaman Jatimakmur' 'KY021 - Kebuli Yaman Cikeas'
#  'KY023 - Kebuli Yaman Pondok Kelapa' 'KY027 - Kebuli Yaman Kaliabang'
#  'KY033 - Kebuli Yaman Jatiasih' 'KY037 - Kebuli Yaman Hankam'
#  'KY045 - Kebuli Yaman Graha Raya' 'KY031 - Kebuli Yaman Perum'
#  'KY038 - Kebuli Yaman Talaga Bestari' 'KY026 - Kebuli Yaman Poris'
#  'KY049 - Kebuli Yaman Bukit Dago' 'KY020 - Kebuli Yaman Tambun'
#  'KY029 - Kebuli Yaman Cinere' 'KY036 - Kebuli Yaman Kota Harapan Indah'
#  'KY007 - Kebuli Yaman Cibubur' 'KY008 - Kebuli Yaman Depok Kelapa Dua'
#  'KY048 - Kebuli Yaman Banjar Wijaya' 'KY003 - Kebuli Yaman Serang'
#  'KY005 - Kebuli Yaman Pandeglang' 'KY004 - Kebuli Yaman Depok Sawangan'
#  'KY011 - Kebuli Yaman Bekasi Galaxy' 'KY009 - Kebuli Yaman Cipinang'
#  'KY002 - Kebuli Yaman Cilegon' 'KY010 - Kebuli Yaman Bogor Ciampea'
#  'KY014 - Kebuli Yaman Ciparay' 'KY041 - Kebuli Yaman Sepatan'
#  'KY028 - Kebuli Yaman Condet' 'KY012 - Kebuli Yaman Cibinong'
#  'KY047 - Kebuli Yaman Ciomas' 'KY013 - Kebuli Yaman Cileunyi'
#  'KY046 - Kebuli Yaman Aryana Karawaci' 'KY035 - Kebuli Yaman Antapani'
#  'KY040 - Kebuli Yaman Anyer' 'KY043 - Kebuli Yaman Taman Cibodas'
#  'KY044 - Kebuli Yaman Pahlawan Bogor' 'KY068 - Kebuli Yaman Kramatwatu'
#  'KY056 - Kebuli Yaman Tigaraksa' 'KY051 - kebuli Yaman TOD M1 Bandara'
#  'KY050 - Kebuli Yaman TangCity Mall'
#  'KY052 - Kebuli Yaman Bantarjati Bogor'
#  'KY053 - Kebuli Yaman Cimanggu Bogor' 'KY054 - Kebuli Yaman Jagakarsa'
#  'KY055 - Kebuli Yaman Ciputat Timur'
#  'KY057 - Kebuli Yaman Rawalumbu (Bekasi)' 'KY058 - Kebuli Yaman Cikande'
#  'KY059 - Kebuli Yaman Dukuh Zamrud' 'KY060 - Kebuli Yaman Pakuhaji'
#  'KY061 - Kebuli Yaman Taman Kirana' 'KY062 - Kebuli Yaman Kampung Baru'
#  'KY063 - Kebuli Yaman Kedaung' 'KY064 - Kebuli Yaman Mutiara Garuda'
#  'KY065 - Kebuli Yaman Sangiang' 'KY067 - Kebuli Yaman Metland'
#  'KY066 - Kebuli Yaman Parung' 'KY069 - Kebuli Yaman Bekasi Galaxy'
#  'KY070 - Kebuli Yaman Cadas' 'KY071 - Kebuli Yaman Citayam'
#  'KY072 - Kebuli Yaman Bintara' 'KY073 - Kebuli Yaman Cilebut'
#  'Kebab Saudagar - Kutabumi']
# --------------------------------------------------
# --- Data available in 'Satuan' ---
# ['Potong' 'Porsi' 'Botol' 'PCS' 'Kg' 'Pack' 'Galon' 'Gr' 'Roll' 'Ekor'
#  'Cup' 'Bungkus']
# --------------------------------------------------

# %%
# Shows all 67 branches, sorted from most frequent to least frequent
with pd.option_context('display.max_rows', None):
    # Use display() and .to_frame() to create a neat, scrollable table
    display(dataset['Nama Cabang'].value_counts().to_frame())
# Out:
#                                           count
# Nama Cabang
# KY001 - Kebuli Yaman Kutabumi (Pusat)     20032
# KY042 - Kebuli Yaman Batavia              17118
# KY041 - Kebuli Yaman Sepatan              16695
# KY007 - Kebuli Yaman Cibubur              16331
# KY003 - Kebuli Yaman Serang               16231
# KY016 - Kebuli Yaman Jatimakmur           16199
# KY040 - Kebuli Yaman Anyer                15947
# KY006 - Kebuli Yaman Depok Sentosa        15944
# KY002 - Kebuli Yaman Cilegon              15827
# KY022 - Kebuli Yaman Citra Raya           15663
# KY005 - Kebuli Yaman Pandeglang           15562
# KY012 - Kebuli Yaman Cibinong             15368
# KY038 - Kebuli Yaman Talaga Bestari       15051
# KY048 - Kebuli Yaman Banjar Wijaya        14816
# KY010 - Kebuli Yaman Bogor Ciampea        14794
# KY026 - Kebuli Yaman Poris                14596
# KY044 - Kebuli Yaman Pahlawan Bogor       14345
# KY008 - Kebuli Yaman Depok Kelapa Dua     14230
# KY045 - Kebuli Yaman Graha Raya           13913
# KY049 - Kebuli Yaman Bukit Dago           13877
# KY027 - Kebuli Yaman Kaliabang            13707
# KY037 - Kebuli Yaman Hankam               13632
# KY021 - Kebuli Yaman Cikeas               13481
# KY036 - Kebuli Yaman Kota Harapan Indah   13411
# KY004 - Kebuli Yaman Depok Sawangan       13400
# KY013 - Kebuli Yaman Cileunyi             13362
# KY029 - Kebuli Yaman Cinere               13351
# KY009 - Kebuli Yaman Cipinang             13250
# KY033 - Kebuli Yaman Jatiasih             12430
# KY056 - Kebuli Yaman Tigaraksa            12218
# KY031 - Kebuli Yaman Perum                12038
# KY028 - Kebuli Yaman Condet               11874
# KY019 - Kebuli Yaman Ciledug              11628
# KY068 - Kebuli Yaman Kramatwatu           11549
# KY014 - Kebuli Yaman Ciparay              11232
# KY020 - Kebuli Yaman Tambun               11094
# KY032 - Kebuli Yaman Kelapa Dua Karawaci  10995
# KY054 - Kebuli Yaman Jagakarsa            10903
# KY043 - Kebuli Yaman Taman Cibodas        10826
# KY052 - Kebuli Yaman Bantarjati Bogor     10794
# KY023 - Kebuli Yaman Pondok Kelapa        10778
# KY047 - Kebuli Yaman Ciomas               10410
# KY053 - Kebuli Yaman Cimanggu Bogor       10304
# KY046 - Kebuli Yaman Aryana Karawaci       9005
# KY051 - kebuli Yaman TOD M1 Bandara        8681
# KY058 - Kebuli Yaman Cikande               8544
# KY057 - Kebuli Yaman Rawalumbu (Bekasi)    7912
# KY055 - Kebuli Yaman Ciputat Timur         7438
# KY050 - Kebuli Yaman TangCity Mall         6643
# KY060 - Kebuli Yaman Pakuhaji              6346
# KY062 - Kebuli Yaman Kampung Baru          6102
# KY061 - Kebuli Yaman Taman Kirana          6021
# KY063 - Kebuli Yaman Kedaung               5806
# KY059 - Kebuli Yaman Dukuh Zamrud          5626
# KY064 - Kebuli Yaman Mutiara Garuda        5193
# KY067 - Kebuli Yaman Metland               4002
# KY065 - Kebuli Yaman Sangiang              3895
# KY066 - Kebuli Yaman Parung                3773
# KY069 - Kebuli Yaman Bekasi Galaxy         3265
# KY070 - Kebuli Yaman Cadas                 1690
# KY071 - Kebuli Yaman Citayam               1146
# KY011 - Kebuli Yaman Bekasi Galaxy          905
# KY035 - Kebuli Yaman Antapani               779
# KY072 - Kebuli Yaman Bintara                685
# TOD M1 Bandara                              481
# KY073 - Kebuli Yaman Cilebut                284
# Kebab Saudagar - Kutabumi                   137
